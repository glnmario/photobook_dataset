# %%
import numpy as np
import pickle
import json
import os
import pandas as pd
from tqdm.notebook import tqdm
from processor import Log
from collections import defaultdict

# %%
def load_logs(log_repository, data_path):
    filepath = os.path.join(data_path, log_repository)
    print("Loading logs from {}...".format(filepath))

    missing_counter = 0
    file_count = 0
    for _, _, files in os.walk(filepath):
        file_count += len(files)
    print("{} files found.".format(file_count))
    logs = []
    for root, dirs, files in os.walk(filepath):
        for file in files:
            if file.endswith(".json"):
                with open(os.path.join(root, file), 'r') as logfile:
                    log = Log(json.load(logfile))
                    if log.complete:
                        logs.append(log)

    print("DONE. Loaded {} completed game logs.".format(len(logs)))
    return logs


def collect_dataset(logs):
    labels = ["Game_ID", "Game_Domain_ID", "Game_Domain_1", "Game_Domain_2", "Game_Duration", "Game_Score", \
              "Feedback_A", "Feedback_B", 'Agent_1', "Agent_2", \
              "Round_Nr", "Round_Duration", "Round_Scores", "Round_Images_A", "Round_Images_B", \
              "Round_Common", "Round_Highlighted_A", "Round_Highlighted_B", \
              "Message_Nr", "Message_Timestamp", "Message_Turn", "Message_Agent_ID", \
              "Message_Speaker", "Message_Type", "Message_Text"]
    dataset = []
    for log in logs:
        game_data = [log.game_id, log.domain_id, log.domains[0], log.domains[1], log.duration.total_seconds(),
                     log.total_score, log.feedback["A"], log.feedback["B"], log.agent_ids[0], log.agent_ids[1]]
        for game_round in log.rounds:
            round_data = [game_round.round_nr - 1, game_round.duration.total_seconds(), game_round.total_score,
                          game_round.images["A"], game_round.images["B"], game_round.common,
                          game_round.highlighted["A"], game_round.highlighted["B"]]
            for message in game_round.messages:
                message_data = [message.message_id, message.timestamp, message.turn, message.agent_id, \
                                message.speaker, message.type, message.text]
                dataset.append(game_data + round_data + message_data)

    df = pd.DataFrame(dataset, columns=labels)

    return df


def remove_prefixing_zeros(s):
    if s[0] == 0:
        return remove_prefixing_zeros(s[1:])
    else:
        return s


def path_to_id(path):
    id_str = path.split('/')[1].split('.')[0].split('_')[-1]
    id_str = remove_prefixing_zeros(id_str)
    return int(id_str)

# %% [markdown]
# ---

# %%
with open('visual_genome/attributes.json', 'r') as f:
    A = json.loads(f.read())
    
with open('visual_genome/relationships.json', 'r') as f:
    R = json.loads(f.read())

# %%
logs = load_logs('logs', '')
dataset = collect_dataset(logs)

F = ['Round_Images_A', 'Round_Images_B']
f2i = {field: i for i, field in enumerate(F)}
# Out:
# Loading logs from logs...
# 2502 files found.
# DONE. Loaded 2502 completed game logs.

# %%
all_pb_images = set()

for index, row in tqdm(dataset.iterrows(), total=len(dataset)):
    for field in F:
        for im in row[field]:
            all_pb_images.add(im)

all_pb_images = list(all_pb_images)
# Out:
# HBox(children=(IntProgress(value=0, max=294370), HTML(value='')))
# ['person_couch/COCO_train2014_000000388344.jpg',
#  'person_bench/COCO_train2014_000000449919.jpg',
#  'person_bench/COCO_train2014_000000015354.jpg',
#  'couch_laptop/COCO_train2014_000000297632.jpg',
#  'person_elephant/COCO_train2014_000000065220.jpg',
#  'person_refrigerator/COCO_train2014_000000005373.jpg',
#  'car_motorcycle/COCO_train2014_000000480807.jpg',
#  'person_motorcycle/COCO_train2014_000000226176.jpg',
#  'person_umbrella/COCO_train2014_000000568064.jpg',
#  'person_elephant/COCO_train2014_000000571351.jpg',
#  'person_oven/COCO_train2014_000000136200.jpg',
#  'person_umbrella/COCO_train2014_000000205931.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000130011.jpg',
#  'person_tv/COCO_train2014_000000544994.jpg',
#  'person_tv/COCO_train2014_000000420617.jpg',
#  'person_bicycle/COCO_train2014_000000326202.jpg',
#  'person_bed/COCO_train2014_000000528563.jpg',
#  'person_truck/COCO_train2014_000000087219.jpg',
#  'couch_dining_table/COCO_train2014_000000180606.jpg',
#  'person_cake/COCO_train2014_000000343799.jpg',
#  'bowl_dining_table/COCO_train2014_000000310714.jpg',
#  'couch_laptop/COCO_train2014_000000452004.jpg',
#  'cup_dining_table/COCO_train2014_000000038305.jpg',
#  'car_truck/COCO_train2014_000000379766.jpg',
#  'person_car/COCO_train2014_000000440460.jpg',
#  'person_tv/COCO_train2014_000000400064.jpg',
#  'person_refrigerator/COCO_train2014_000000107157.jpg',
#  'couch_dining_table/COCO_train2014_000000551303.jpg',
#  'person_truck/COCO_train2014_000000190016.jpg',
#  'person_umbrella/COCO_train2014_000000122731.jpg',
#  'person_car/COCO_train2014_000000195449.jpg',
#  'car_truck/COCO_train2014_000000237372.jpg',
#  'person_refrigerator/COCO_train2014_000000324732.jpg',
#  'person_surfboard/COCO_train2014_000000387812.jpg',
#  'cup_dining_table/COCO_train2014_000000566432.jpg',
#  'person_suitcase/COCO_train2014_000000206968.jpg',
#  'person_elephant/COCO_train2014_000000013763.jpg',
#  'person_surfboard/COCO_train2014_000000340331.jpg',
#  'person_motorcycle/COCO_train2014_000000198072.jpg',
#  'person_motorcycle/COCO_train2014_000000324228.jpg',
#  'cake_dining_table/COCO_train2014_000000134238.jpg',
#  'person_car/COCO_train2014_000000563545.jpg',
#  'bus_truck/COCO_train2014_000000557394.jpg',
#  'person_umbrella/COCO_train2014_000000438896.jpg',
#  'person_motorcycle/COCO_train2014_000000122863.jpg',
#  'bowl_dining_table/COCO_train2014_000000086285.jpg',
#  'person_tv/COCO_train2014_000000403999.jpg',
#  'car_motorcycle/COCO_train2014_000000215201.jpg',
#  'person_truck/COCO_train2014_000000099245.jpg',
#  'person_bicycle/COCO_train2014_000000256981.jpg',
#  'person_bicycle/COCO_train2014_000000098596.jpg',
#  'person_oven/COCO_train2014_000000031084.jpg',
#  'bus_truck/COCO_train2014_000000483534.jpg',
#  'person_motorcycle/COCO_train2014_000000039100.jpg',
#  'person_oven/COCO_train2014_000000481144.jpg',
#  'person_bed/COCO_train2014_000000112029.jpg',
#  'person_umbrella/COCO_train2014_000000209787.jpg',
#  'person_refrigerator/COCO_train2014_000000459209.jpg',
#  'cake_dining_table/COCO_train2014_000000381996.jpg',
#  'cup_dining_table/COCO_train2014_000000439518.jpg',
#  'person_dog/COCO_train2014_000000344597.jpg',
#  'person_surfboard/COCO_train2014_000000572061.jpg',
#  'person_motorcycle/COCO_train2014_000000279373.jpg',
#  'person_bicycle/COCO_train2014_000000386326.jpg',
#  'cake_dining_table/COCO_train2014_000000126144.jpg',
#  'person_boat/COCO_train2014_000000461183.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000043256.jpg',
#  'person_teddy_bear/COCO_train2014_000000340923.jpg',
#  'person_cake/COCO_train2014_000000126144.jpg',
#  'car_truck/COCO_train2014_000000137150.jpg',
#  'person_train/COCO_train2014_000000525163.jpg',
#  'person_suitcase/COCO_train2014_000000175391.jpg',
#  'person_bench/COCO_train2014_000000140762.jpg',
#  'cake_dining_table/COCO_train2014_000000134599.jpg',
#  'person_elephant/COCO_train2014_000000204759.jpg',
#  'person_elephant/COCO_train2014_000000524059.jpg',
#  'car_motorcycle/COCO_train2014_000000024608.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000449904.jpg',
#  'person_motorcycle/COCO_train2014_000000168627.jpg',
#  'car_truck/COCO_train2014_000000075299.jpg',
#  'couch_laptop/COCO_train2014_000000166853.jpg',
#  'person_truck/COCO_train2014_000000035995.jpg',
#  'person_suitcase/COCO_train2014_000000160471.jpg',
#  'bus_truck/COCO_train2014_000000400091.jpg',
#  'person_teddy_bear/COCO_train2014_000000184930.jpg',
#  'couch_laptop/COCO_train2014_000000474562.jpg',
#  'couch_dining_table/COCO_train2014_000000330652.jpg',
#  'person_cake/COCO_train2014_000000481931.jpg',
#  'bowl_dining_table/COCO_train2014_000000260248.jpg',
#  'chair_couch/COCO_train2014_000000410024.jpg',
#  'person_car/COCO_train2014_000000461187.jpg',
#  'couch_dining_table/COCO_train2014_000000560969.jpg',
#  'person_truck/COCO_train2014_000000418229.jpg',
#  'chair_couch/COCO_train2014_000000581136.jpg',
#  'cup_dining_table/COCO_train2014_000000172135.jpg',
#  'person_elephant/COCO_train2014_000000576598.jpg',
#  'person_motorcycle/COCO_train2014_000000560615.jpg',
#  'person_couch/COCO_train2014_000000494341.jpg',
#  'person_boat/COCO_train2014_000000492268.jpg',
#  'person_bench/COCO_train2014_000000039360.jpg',
#  'person_suitcase/COCO_train2014_000000538682.jpg',
#  'chair_couch/COCO_train2014_000000131927.jpg',
#  'person_truck/COCO_train2014_000000032674.jpg',
#  'bowl_dining_table/COCO_train2014_000000100022.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000330112.jpg',
#  'person_teddy_bear/COCO_train2014_000000419186.jpg',
#  'person_oven/COCO_train2014_000000118694.jpg',
#  'person_suitcase/COCO_train2014_000000037327.jpg',
#  'bus_truck/COCO_train2014_000000349931.jpg',
#  'couch_laptop/COCO_train2014_000000233786.jpg',
#  'person_cake/COCO_train2014_000000447941.jpg',
#  'couch_dining_table/COCO_train2014_000000275014.jpg',
#  'person_cake/COCO_train2014_000000488127.jpg',
#  'person_suitcase/COCO_train2014_000000200221.jpg',
#  'chair_couch/COCO_train2014_000000119002.jpg',
#  'dining_table_laptop/COCO_train2014_000000524866.jpg',
#  'person_suitcase/COCO_train2014_000000113123.jpg',
#  'couch_laptop/COCO_train2014_000000174573.jpg',
#  'person_couch/COCO_train2014_000000349932.jpg',
#  'cup_dining_table/COCO_train2014_000000570019.jpg',
#  'car_truck/COCO_train2014_000000255975.jpg',
#  'car_motorcycle/COCO_train2014_000000054286.jpg',
#  'bowl_dining_table/COCO_train2014_000000492731.jpg',
#  'person_bed/COCO_train2014_000000384160.jpg',
#  'cake_dining_table/COCO_train2014_000000392943.jpg',
#  'person_motorcycle/COCO_train2014_000000212969.jpg',
#  'person_bed/COCO_train2014_000000314846.jpg',
#  'couch_dining_table/COCO_train2014_000000109895.jpg',
#  'person_boat/COCO_train2014_000000012574.jpg',
#  'person_couch/COCO_train2014_000000182812.jpg',
#  'person_car/COCO_train2014_000000011619.jpg',
#  'person_suitcase/COCO_train2014_000000553308.jpg',
#  'dining_table_laptop/COCO_train2014_000000014238.jpg',
#  'person_bicycle/COCO_train2014_000000293658.jpg',
#  'person_oven/COCO_train2014_000000162573.jpg',
#  'person_cake/COCO_train2014_000000055912.jpg',
#  'person_surfboard/COCO_train2014_000000111385.jpg',
#  'bowl_dining_table/COCO_train2014_000000244425.jpg',
#  'person_oven/COCO_train2014_000000550438.jpg',
#  'person_car/COCO_train2014_000000121619.jpg',
#  'person_car/COCO_train2014_000000126097.jpg',
#  'car_truck/COCO_train2014_000000115639.jpg',
#  'person_train/COCO_train2014_000000066337.jpg',
#  'couch_laptop/COCO_train2014_000000407139.jpg',
#  'person_couch/COCO_train2014_000000042741.jpg',
#  'person_suitcase/COCO_train2014_000000086922.jpg',
#  'chair_couch/COCO_train2014_000000408925.jpg',
#  'person_tv/COCO_train2014_000000288713.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000075726.jpg',
#  'person_bicycle/COCO_train2014_000000266311.jpg',
#  'car_motorcycle/COCO_train2014_000000127400.jpg',
#  'person_bed/COCO_train2014_000000318646.jpg',
#  'car_motorcycle/COCO_train2014_000000494833.jpg',
#  'person_teddy_bear/COCO_train2014_000000358113.jpg',
#  'person_surfboard/COCO_train2014_000000314741.jpg',
#  'person_elephant/COCO_train2014_000000296747.jpg',
#  'person_umbrella/COCO_train2014_000000036282.jpg',
#  'person_bed/COCO_train2014_000000034825.jpg',
#  'person_tv/COCO_train2014_000000263385.jpg',
#  'person_car/COCO_train2014_000000405991.jpg',
#  'couch_dining_table/COCO_train2014_000000336942.jpg',
#  'cup_dining_table/COCO_train2014_000000131498.jpg',
#  'person_elephant/COCO_train2014_000000041649.jpg',
#  'person_oven/COCO_train2014_000000560784.jpg',
#  'person_tv/COCO_train2014_000000493114.jpg',
#  'person_surfboard/COCO_train2014_000000374388.jpg',
#  'person_train/COCO_train2014_000000089902.jpg',
#  'person_cake/COCO_train2014_000000084211.jpg',
#  'car_motorcycle/COCO_train2014_000000144597.jpg',
#  'person_bicycle/COCO_train2014_000000495580.jpg',
#  'chair_couch/COCO_train2014_000000512515.jpg',
#  'cup_dining_table/COCO_train2014_000000035407.jpg',
#  'bowl_dining_table/COCO_train2014_000000132002.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000311337.jpg',
#  'cup_dining_table/COCO_train2014_000000163939.jpg',
#  'person_dog/COCO_train2014_000000145499.jpg',
#  'person_boat/COCO_train2014_000000289248.jpg',
#  'bus_truck/COCO_train2014_000000472103.jpg',
#  'person_train/COCO_train2014_000000181064.jpg',
#  'dining_table_laptop/COCO_train2014_000000468357.jpg',
#  'person_dog/COCO_train2014_000000515186.jpg',
#  'couch_dining_table/COCO_train2014_000000010877.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000303703.jpg',
#  'person_bed/COCO_train2014_000000348269.jpg',
#  'bowl_dining_table/COCO_train2014_000000161846.jpg',
#  'cake_dining_table/COCO_train2014_000000501718.jpg',
#  'person_umbrella/COCO_train2014_000000164634.jpg',
#  'car_motorcycle/COCO_train2014_000000293647.jpg',
#  'person_dog/COCO_train2014_000000283451.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000177775.jpg',
#  'dining_table_laptop/COCO_train2014_000000082894.jpg',
#  'person_bicycle/COCO_train2014_000000034815.jpg',
#  'dining_table_laptop/COCO_train2014_000000420523.jpg',
#  'person_elephant/COCO_train2014_000000033416.jpg',
#  'person_couch/COCO_train2014_000000226817.jpg',
#  'person_train/COCO_train2014_000000480295.jpg',
#  'person_bench/COCO_train2014_000000220226.jpg',
#  'couch_dining_table/COCO_train2014_000000580057.jpg',
#  'car_truck/COCO_train2014_000000056549.jpg',
#  'bowl_dining_table/COCO_train2014_000000356290.jpg',
#  'person_dog/COCO_train2014_000000324156.jpg',
#  'bus_truck/COCO_train2014_000000327330.jpg',
#  'chair_couch/COCO_train2014_000000269431.jpg',
#  'bus_truck/COCO_train2014_000000349204.jpg',
#  'person_bicycle/COCO_train2014_000000441488.jpg',
#  'person_cake/COCO_train2014_000000475999.jpg',
#  'person_cake/COCO_train2014_000000052928.jpg',
#  'person_dog/COCO_train2014_000000420316.jpg',
#  'person_dog/COCO_train2014_000000194698.jpg',
#  'person_truck/COCO_train2014_000000292358.jpg',
#  'cake_dining_table/COCO_train2014_000000235744.jpg',
#  'person_dog/COCO_train2014_000000421393.jpg',
#  'person_teddy_bear/COCO_train2014_000000151764.jpg',
#  'couch_dining_table/COCO_train2014_000000456988.jpg',
#  'person_bench/COCO_train2014_000000196545.jpg',
#  'person_surfboard/COCO_train2014_000000097094.jpg',
#  'person_bench/COCO_train2014_000000372319.jpg',
#  'dining_table_laptop/COCO_train2014_000000380128.jpg',
#  'person_refrigerator/COCO_train2014_000000204987.jpg',
#  'person_car/COCO_train2014_000000258505.jpg',
#  'person_couch/COCO_train2014_000000133384.jpg',
#  'person_couch/COCO_train2014_000000536570.jpg',
#  'car_truck/COCO_train2014_000000339250.jpg',
#  'bus_truck/COCO_train2014_000000274196.jpg',
#  'car_motorcycle/COCO_train2014_000000514839.jpg',
#  'person_suitcase/COCO_train2014_000000257858.jpg',
#  'bowl_dining_table/COCO_train2014_000000386603.jpg',
#  'person_tv/COCO_train2014_000000210471.jpg',
#  'person_truck/COCO_train2014_000000237372.jpg',
#  'person_boat/COCO_train2014_000000436717.jpg',
#  'person_boat/COCO_train2014_000000167783.jpg',
#  'person_umbrella/COCO_train2014_000000354843.jpg',
#  'car_truck/COCO_train2014_000000151371.jpg',
#  'person_boat/COCO_train2014_000000004834.jpg',
#  'car_motorcycle/COCO_train2014_000000477807.jpg',
#  'bowl_dining_table/COCO_train2014_000000144797.jpg',
#  'person_dog/COCO_train2014_000000171262.jpg',
#  'person_surfboard/COCO_train2014_000000287084.jpg',
#  'person_teddy_bear/COCO_train2014_000000319818.jpg',
#  'person_refrigerator/COCO_train2014_000000040338.jpg',
#  'car_truck/COCO_train2014_000000565975.jpg',
#  'person_refrigerator/COCO_train2014_000000449904.jpg',
#  'person_bed/COCO_train2014_000000560909.jpg',
#  'person_surfboard/COCO_train2014_000000204735.jpg',
#  'couch_laptop/COCO_train2014_000000145629.jpg',
#  'dining_table_laptop/COCO_train2014_000000522129.jpg',
#  'cup_dining_table/COCO_train2014_000000304858.jpg',
#  'cup_dining_table/COCO_train2014_000000105733.jpg',
#  'person_oven/COCO_train2014_000000439463.jpg',
#  'person_dog/COCO_train2014_000000402297.jpg',
#  'person_surfboard/COCO_train2014_000000515743.jpg',
#  'person_boat/COCO_train2014_000000191616.jpg',
#  'chair_couch/COCO_train2014_000000461340.jpg',
#  'person_car/COCO_train2014_000000282514.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000317237.jpg',
#  'person_cake/COCO_train2014_000000478537.jpg',
#  'person_oven/COCO_train2014_000000080311.jpg',
#  'car_motorcycle/COCO_train2014_000000345207.jpg',
#  'person_bench/COCO_train2014_000000032957.jpg',
#  'chair_couch/COCO_train2014_000000399122.jpg',
#  'car_truck/COCO_train2014_000000456453.jpg',
#  'person_couch/COCO_train2014_000000039570.jpg',
#  'person_car/COCO_train2014_000000394151.jpg',
#  'person_dog/COCO_train2014_000000080394.jpg',
#  'person_umbrella/COCO_train2014_000000210266.jpg',
#  'person_dog/COCO_train2014_000000522288.jpg',
#  'person_train/COCO_train2014_000000313709.jpg',
#  'couch_laptop/COCO_train2014_000000179961.jpg',
#  'person_refrigerator/COCO_train2014_000000254658.jpg',
#  'person_truck/COCO_train2014_000000265781.jpg',
#  'person_bench/COCO_train2014_000000239417.jpg',
#  'dining_table_laptop/COCO_train2014_000000096757.jpg',
#  'bus_truck/COCO_train2014_000000253054.jpg',
#  'person_tv/COCO_train2014_000000323226.jpg',
#  'dining_table_laptop/COCO_train2014_000000341060.jpg',
#  'cup_dining_table/COCO_train2014_000000496196.jpg',
#  'bus_truck/COCO_train2014_000000308175.jpg',
#  'person_train/COCO_train2014_000000178018.jpg',
#  'person_bench/COCO_train2014_000000335696.jpg',
#  'person_elephant/COCO_train2014_000000337304.jpg',
#  'person_umbrella/COCO_train2014_000000546408.jpg',
#  'person_refrigerator/COCO_train2014_000000418620.jpg',
#  'person_motorcycle/COCO_train2014_000000270912.jpg',
#  'bus_truck/COCO_train2014_000000485064.jpg',
#  'person_truck/COCO_train2014_000000258505.jpg',
#  'person_motorcycle/COCO_train2014_000000238178.jpg',
#  'person_surfboard/COCO_train2014_000000079720.jpg',
#  'person_train/COCO_train2014_000000085179.jpg',
#  'person_umbrella/COCO_train2014_000000489469.jpg',
#  'person_teddy_bear/COCO_train2014_000000207354.jpg',
#  'person_refrigerator/COCO_train2014_000000497591.jpg',
#  'car_truck/COCO_train2014_000000468408.jpg',
#  'bowl_dining_table/COCO_train2014_000000395097.jpg',
#  'person_bicycle/COCO_train2014_000000386722.jpg',
#  'person_elephant/COCO_train2014_000000095257.jpg',
#  'couch_dining_table/COCO_train2014_000000509555.jpg',
#  'chair_couch/COCO_train2014_000000002347.jpg',
#  'person_suitcase/COCO_train2014_000000187582.jpg',
#  'cake_dining_table/COCO_train2014_000000545573.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000096222.jpg',
#  'person_oven/COCO_train2014_000000305709.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000305451.jpg',
#  'person_train/COCO_train2014_000000246396.jpg',
#  'person_refrigerator/COCO_train2014_000000217700.jpg',
#  'dining_table_refrigerator/COCO_train2014_000000213135.jpg',
#  'person_cake/COCO_train2014_000000210010.jpg',
#  'couch_laptop/COCO_train2014_000000469405.jpg',
#  'person_motorcycle/COCO_train2014_000000210052.jpg',
#  'cake_dining_table/COCO_train2014_000000336593.jpg',
#  'person_truck/COCO_train2014_000000227003.jpg',
#  'cake_dining_table/COCO_train2014_000000322720.jpg',
#  'cake_dining_table/COCO_train2014_000000222244.jpg',
#  'car_motorcycle/COCO_train2014_000000256560.jpg',
#  'dining_table_laptop/COCO_train2014_000000259745.jpg',
#  'person_car/COCO_train2014_000000425647.jpg',
#  'person_train/COCO_train2014_000000382203.jpg',
#  'person_tv/COCO_train2014_000000160102.jpg',
#  'person_suitcase/COCO_train2014_000000184319.jpg',
#  'person_train/COCO_train2014_000000420151.jpg',
#  'person_bed/COCO_train2014_000000029642.jpg',
#  'person_truck/COCO_train2014_000000185945.jpg',
#  'dining_table_laptop/COCO_train2014_000000483794.jpg',
#  'person_tv/COCO_train2014_000000035771.jpg',
#  'person_refrigerator/COCO_train2014_000000305451.jpg',
#  'person_couch/COCO_train2014_000000228000.jpg',
#  'person_couch/COCO_train2014_000000024105.jpg',
#  'person_teddy_bear/COCO_train2014_000000136701.jpg',
#  'person_bench/COCO_train2014_000000326499.jpg',
#  'person_bed/COCO_train2014_000000425325.jpg',
#  'person_boat/COCO_train2014_000000424434.jpg',
#  'person_bed/COCO_train2014_000000354532.jpg',
#  'person_teddy_bear/COCO_train2014_000000127441.jpg',
#  'person_teddy_bear/COCO_train2014_000000374391.jpg',
#  'cake_dining_table/COCO_train2014_000000152914.jpg',
#  'person_elephant/COCO_train2014_000000532644.jpg',
#  'person_train/COCO_train2014_000000010275.jpg',
#  'person_surfboard/COCO_train2014_000000083580.jpg',
#  'couch_laptop/COCO_train2014_000000380128.jpg',
#  'person_teddy_bear/COCO_train2014_000000231675.jpg',
#  'cup_dining_table/COCO_train2014_000000316663.jpg',
#  'person_bicycle/COCO_train2014_000000086189.jpg',
#  'person_boat/COCO_train2014_000000302166.jpg',
#  'person_bed/COCO_train2014_000000575631.jpg',
#  'couch_dining_table/COCO_train2014_000000249727.jpg',
#  'person_umbrella/COCO_train2014_000000159965.jpg',
#  'person_bench/COCO_train2014_000000580257.jpg',
#  'person_oven/COCO_train2014_000000203730.jpg',
#  'person_oven/COCO_train2014_000000277990.jpg',
#  'person_boat/COCO_train2014_000000079517.jpg',
#  'person_teddy_bear/COCO_train2014_000000157714.jpg',
#  'chair_couch/COCO_train2014_000000341797.jpg',
#  'bus_truck/COCO_train2014_000000509321.jpg',
#  'person_couch/COCO_train2014_000000374239.jpg',
#  'person_cake/COCO_train2014_000000405246.jpg',
#  'chair_couch/COCO_train2014_000000462712.jpg',
#  'person_boat/COCO_train2014_000000211892.jpg',
#  'dining_table_laptop/COCO_train2014_000000093469.jpg',
#  'person_tv/COCO_train2014_000000475957.jpg',
#  'couch_laptop/COCO_train2014_000000292101.jpg',
#  'person_bicycle/COCO_train2014_000000527112.jpg']

# %%
all_pb_image_ids = {path_to_id(path): path for path in all_pb_images}

# %%
with open('visual_genome/image_data.json', 'r') as f:
    idata = json.loads(f.read())
    
coco2imageid = {}
image2cocoid = {}

for idatum in idata:
    coco_id = idatum['coco_id']
    if coco_id and coco_id in all_pb_image_ids:
        coco2imageid[coco_id] = idatum['image_id']
        image2cocoid[idatum['image_id']] = coco_id

# %%
relevant_ids = []
for path in all_pb_images:
    try:
        relevant_ids.append(coco2imageid[path_to_id(path)])
    except KeyError:
        relevant_ids.append(None)

# %%
attributes = defaultdict(set)

for entry in A:
    if entry['image_id'] not in relevant_ids:
        continue

    coco_id = image2cocoid[entry['image_id']]
    im_path = all_pb_image_ids[coco_id]

    for att in entry['attributes']:
        try:
            entity_attributes = set([a.lower() for a in att['attributes']])
        except KeyError:
            entity_attributes = set()

        entity_names = set()
        for phrase in att['names']:
            for tok in phrase.split(' '):
                entity_names.add(tok.lower())
        
        attributes[im_path] |= (entity_names | entity_attributes)

# %%
relations = defaultdict(set)

for entry in R:
    if entry['image_id'] not in relevant_ids:
        continue

    coco_id = image2cocoid[entry['image_id']]
    im_path = all_pb_image_ids[coco_id]
    
    for rel in entry['relationships']:
        predicate = rel['predicate'].lower().split(' ')
        subject = rel['subject']['name'].lower().split(' ')
        object = rel['object']['name'].lower().split(' ')
        
        relations[im_path] |= set(predicate + subject + object)
        
#         try:
#             entity_attributes = set(att['attributes'])
#         except KeyError:
#             entity_attributes = set()

#         entity_names = set()
#         for phrase in att['names']:
#             for tok in phrase.split(' '):
#                 entity_names.add(tok)
        
#         attributes[im_path] |= (entity_names | entity_attributes)

# %%
with open('visual_genome/attributes.dict', 'wb') as f:
    pickle.dump(attributes, file=f)
    
with open('visual_genome/relationships.dict', 'wb') as f:
    pickle.dump(relations, file=f)

# %%
with open('visual_genome/attributes.dict', 'rb') as f:
    vg_attributes = pickle.load(f)

# %%
relations['person_train/COCO_train2014_000000010275.jpg']
# Out:
# {'and',
#  'barrette',
#  'beige',
#  'black',
#  'both',
#  'brick',
#  'broken',
#  'brown',
#  'camel',
#  'chin',
#  'coat',
#  'glasses',
#  'grey',
#  'hair',
#  'hand',
#  'has',
#  'head',
#  'holding',
#  'in',
#  'jacket',
#  'lady',
#  'looks',
#  'man',
#  'no',
#  'nt',
#  'of',
#  'on',
#  'open',
#  'out',
#  'outside',
#  'people',
#  'person',
#  'pony',
#  'rain',
#  'red',
#  'says',
#  'sign',
#  'sleeping',
#  'smoking',
#  'sticker',
#  'striped',
#  'stripes',
#  'tail',
#  'tan',
#  'umbrella',
#  'umbrellas',
#  'wall',
#  'wears',
#  'white',
#  'window',
#  'winter',
#  'with',
#  'woman',
#  'working'}
